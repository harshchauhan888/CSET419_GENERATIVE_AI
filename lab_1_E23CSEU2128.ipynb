# %%
# CSET419 – Generative Artificial Intelligence Lab – 2
# Name: Harsh Chauhan
# Roll No: E23CSEU2128

# %%
"""
Aim:
To study the basic concept of Generative Artificial Intelligence
using a simple Python program.
"""
# Out:
# '\nAim:\nTo study the basic concept of Generative Artificial Intelligence\nusing a simple Python program.\n'

# %%
"""
Generative Artificial Intelligence is a type of AI
that can generate new content such as text, images,
or code using trained data models.
"""
# Out:
# '\nGenerative Artificial Intelligence is a type of AI\nthat can generate new content such as text, images,\nor code using trained data models.\n'

# %%
def simple_gen_ai(text):
    return "AI Output: " + text

print(simple_gen_ai("What is Generative AI?"))
# Out:
# AI Output: What is Generative AI?

# %%
"""
Conclusion:
This lab helped in understanding the basic idea
of Generative AI using Python programming.
"""
# Out:
# '\nConclusion:\nThis lab helped in understanding the basic idea\nof Generative AI using Python programming.\n'
